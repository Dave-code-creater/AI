# %% [markdown]
# # Image Classification

# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# %%
device = "cuda" if torch.cuda.is_available() else "gpu"
device
# Out:
# 'cuda'

# %%
samples = 1000


X,y = make_circles(samples, noise = 0.03)
len(X),len(y)
# Out:
# (1000, 1000)

# %%
# Visualize function
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=y,
            cmap=plt.cm.RdYlBu)

# %%
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
class CircleModelV0(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(2,5)
        self.layer_2 = nn.Linear(5,1)
        
    def forward(self, x)->torch.Tensor:
        return self.layer_2(self.layer_1(X))
    
model_0 = CircleModelV0().to(device)
model_0
# Out:
# CircleModelV0(
#   (layer_1): Linear(in_features=2, out_features=5, bias=True)
#   (layer_2): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
model_0 = nn.Sequential(nn.Linear(2,5),
                         nn.Linear(5,1)).to(device)

# %%
# Loss Function and Optimizer 

loss_fn = nn.BCEWithLogitsLoss()

optimizer = torch.optim.SGD(params = model_0.parameters(),lr = 0.01)

# %%
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct/len(y_pred))*100
    return acc

# %% [markdown]
# # Training loop

# %%
model_0.eval()
with torch.inference_mode():
    y_logits = model_0(X_test.to(device))[:5]
y_logits
# Out:
# tensor([[-0.4542],
#         [-0.3797],
#         [-0.3924],
#         [-0.3080],
#         [-0.1494]], device='cuda:0')

# %%
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs
# Out:
# tensor([[0.3884],
#         [0.4062],
#         [0.4032],
#         [0.4236],
#         [0.4627]], device='cuda:0')

# %%
torch.round(y_pred_probs)
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:0')

# %%
eopchs = 1000

# Move device
X_train = X_train.to(device)
X_test=X_test.to(device)
y_train=y_train.to(device)
y_test=y_test.to(device)

for epoch in range(eopchs):
    
    model_0.train()
    
    y_logits = model_0(X_train).squeeze()
    y_pred = torch.round(torch.sigmoid(y_logits))
    
    loss =loss_fn(y_logits,y_train)
    
    acc = accuracy_fn(y_true=y_train,y_pred=y_pred)
    
    optimizer.zero_grad()
    
    loss.backward()
    
    optimizer.step()
    
    model_0.eval()
    with torch.inference_mode():
        test_logits = model_0(X_test).squeeze()
        test_pred = torch.round(torch.sigmoid(test_logits))
        
        test_loss = loss_fn(test_logits,y_test)
        
        test_acc = accuracy_fn(y_true=y_test,y_pred=test_pred)
        
    if epoch % 10 ==0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Acc: {acc:.2} | Test loss: {test_loss:.5f}, Test accuracy: {test_acc:.2f}")
# Out:
# Epoch: 0 | Loss: 0.70152, Acc: 4.8e+01 | Test loss: 0.69913, Test accuracy: 49.50
# Epoch: 10 | Loss: 0.70104, Acc: 4.9e+01 | Test loss: 0.69877, Test accuracy: 49.00
# Epoch: 20 | Loss: 0.70060, Acc: 4.9e+01 | Test loss: 0.69845, Test accuracy: 48.50
# Epoch: 30 | Loss: 0.70019, Acc: 4.9e+01 | Test loss: 0.69815, Test accuracy: 48.50
# Epoch: 40 | Loss: 0.69982, Acc: 4.9e+01 | Test loss: 0.69788, Test accuracy: 49.00
# Epoch: 50 | Loss: 0.69948, Acc: 5e+01 | Test loss: 0.69763, Test accuracy: 48.50
# Epoch: 60 | Loss: 0.69916, Acc: 4.9e+01 | Test loss: 0.69741, Test accuracy: 48.50
# Epoch: 70 | Loss: 0.69887, Acc: 4.9e+01 | Test loss: 0.69720, Test accuracy: 48.50
# Epoch: 80 | Loss: 0.69859, Acc: 4.8e+01 | Test loss: 0.69701, Test accuracy: 48.50
# Epoch: 90 | Loss: 0.69834, Acc: 4.9e+01 | Test loss: 0.69684, Test accuracy: 49.00
# Epoch: 100 | Loss: 0.69811, Acc: 4.9e+01 | Test loss: 0.69668, Test accuracy: 49.50
# Epoch: 110 | Loss: 0.69789, Acc: 4.8e+01 | Test loss: 0.69654, Test accuracy: 49.50
# Epoch: 120 | Loss: 0.69769, Acc: 4.9e+01 | Test loss: 0.69640, Test accuracy: 49.50
# Epoch: 130 | Loss: 0.69750, Acc: 4.9e+01 | Test loss: 0.69628, Test accuracy: 49.00
# Epoch: 140 | Loss: 0.69732, Acc: 4.9e+01 | Test loss: 0.69616, Test accuracy: 49.00
# Epoch: 150 | Loss: 0.69716, Acc: 4.9e+01 | Test loss: 0.69606, Test accuracy: 49.00
# Epoch: 160 | Loss: 0.69700, Acc: 5e+01 | Test loss: 0.69596, Test accuracy: 49.00
# Epoch: 170 | Loss: 0.69686, Acc: 5e+01 | Test loss: 0.69586, Test accuracy: 48.50
# Epoch: 180 | Loss: 0.69672, Acc: 5e+01 | Test loss: 0.69578, Test accuracy: 47.50
# Epoch: 190 | Loss: 0.69659, Acc: 5e+01 | Test loss: 0.69570, Test accuracy: 48.00
# Epoch: 200 | Loss: 0.69647, Acc: 5e+01 | Test loss: 0.69562, Test accuracy: 48.00
# Epoch: 210 | Loss: 0.69636, Acc: 5e+01 | Test loss: 0.69555, Test accuracy: 47.50
# Epoch: 220 | Loss: 0.69625, Acc: 5e+01 | Test loss: 0.69548, Test accuracy: 47.50
# Epoch: 230 | Loss: 0.69615, Acc: 5e+01 | Test loss: 0.69542, Test accuracy: 49.50
# Epoch: 240 | Loss: 0.69605, Acc: 5e+01 | Test loss: 0.69536, Test accuracy: 49.00
# Epoch: 250 | Loss: 0.69596, Acc: 5e+01 | Test loss: 0.69531, Test accuracy: 49.00
# Epoch: 260 | Loss: 0.69587, Acc: 5.1e+01 | Test loss: 0.69525, Test accuracy: 49.50
# Epoch: 270 | Loss: 0.69579, Acc: 5e+01 | Test loss: 0.69520, Test accuracy: 49.50
# Epoch: 280 | Loss: 0.69571, Acc: 5e+01 | Test loss: 0.69515, Test accuracy: 49.50
# Epoch: 290 | Loss: 0.69563, Acc: 5e+01 | Test loss: 0.69511, Test accuracy: 49.50
# Epoch: 300 | Loss: 0.69556, Acc: 5e+01 | Test loss: 0.69506, Test accuracy: 49.50
# Epoch: 310 | Loss: 0.69549, Acc: 5e+01 | Test loss: 0.69502, Test accuracy: 49.50
# Epoch: 320 | Loss: 0.69543, Acc: 5e+01 | Test loss: 0.69498, Test accuracy: 49.50
# Epoch: 330 | Loss: 0.69536, Acc: 5e+01 | Test loss: 0.69494, Test accuracy: 49.50
# Epoch: 340 | Loss: 0.69530, Acc: 5e+01 | Test loss: 0.69490, Test accuracy: 49.50
# Epoch: 350 | Loss: 0.69524, Acc: 5e+01 | Test loss: 0.69486, Test accuracy: 49.50
# Epoch: 360 | Loss: 0.69519, Acc: 5e+01 | Test loss: 0.69483, Test accuracy: 50.00
# Epoch: 370 | Loss: 0.69513, Acc: 5e+01 | Test loss: 0.69480, Test accuracy: 50.00
# Epoch: 380 | Loss: 0.69508, Acc: 5.1e+01 | Test loss: 0.69476, Test accuracy: 50.00
# Epoch: 390 | Loss: 0.69503, Acc: 5e+01 | Test loss: 0.69473, Test accuracy: 50.00
# Epoch: 400 | Loss: 0.69498, Acc: 5e+01 | Test loss: 0.69470, Test accuracy: 50.00
# Epoch: 410 | Loss: 0.69494, Acc: 5e+01 | Test loss: 0.69467, Test accuracy: 49.50
# Epoch: 420 | Loss: 0.69489, Acc: 5.1e+01 | Test loss: 0.69464, Test accuracy: 49.50
# Epoch: 430 | Loss: 0.69485, Acc: 5e+01 | Test loss: 0.69461, Test accuracy: 49.50
# Epoch: 440 | Loss: 0.69481, Acc: 5e+01 | Test loss: 0.69459, Test accuracy: 49.50
# Epoch: 450 | Loss: 0.69477, Acc: 5e+01 | Test loss: 0.69456, Test accuracy: 49.50
# Epoch: 460 | Loss: 0.69473, Acc: 5e+01 | Test loss: 0.69453, Test accuracy: 49.50
# Epoch: 470 | Loss: 0.69469, Acc: 5e+01 | Test loss: 0.69451, Test accuracy: 50.00
# Epoch: 480 | Loss: 0.69465, Acc: 5.1e+01 | Test loss: 0.69448, Test accuracy: 50.00
# Epoch: 490 | Loss: 0.69461, Acc: 5.1e+01 | Test loss: 0.69446, Test accuracy: 50.00
# Epoch: 500 | Loss: 0.69458, Acc: 5.1e+01 | Test loss: 0.69444, Test accuracy: 50.00
# Epoch: 510 | Loss: 0.69455, Acc: 5.1e+01 | Test loss: 0.69441, Test accuracy: 50.00
# Epoch: 520 | Loss: 0.69451, Acc: 5.1e+01 | Test loss: 0.69439, Test accuracy: 50.00
# Epoch: 530 | Loss: 0.69448, Acc: 5.1e+01 | Test loss: 0.69437, Test accuracy: 50.50
# Epoch: 540 | Loss: 0.69445, Acc: 5.1e+01 | Test loss: 0.69435, Test accuracy: 50.50
# Epoch: 550 | Loss: 0.69442, Acc: 5.1e+01 | Test loss: 0.69433, Test accuracy: 50.00
# Epoch: 560 | Loss: 0.69439, Acc: 5.1e+01 | Test loss: 0.69431, Test accuracy: 50.00
# Epoch: 570 | Loss: 0.69436, Acc: 5.1e+01 | Test loss: 0.69429, Test accuracy: 50.00
# Epoch: 580 | Loss: 0.69433, Acc: 5.1e+01 | Test loss: 0.69427, Test accuracy: 51.00
# Epoch: 590 | Loss: 0.69431, Acc: 5.1e+01 | Test loss: 0.69425, Test accuracy: 51.50
# Epoch: 600 | Loss: 0.69428, Acc: 5.1e+01 | Test loss: 0.69423, Test accuracy: 51.50
# Epoch: 610 | Loss: 0.69425, Acc: 5.1e+01 | Test loss: 0.69421, Test accuracy: 51.50
# Epoch: 620 | Loss: 0.69423, Acc: 5.1e+01 | Test loss: 0.69420, Test accuracy: 51.50
# Epoch: 630 | Loss: 0.69420, Acc: 5.1e+01 | Test loss: 0.69418, Test accuracy: 51.50
# Epoch: 640 | Loss: 0.69418, Acc: 5.1e+01 | Test loss: 0.69416, Test accuracy: 51.50
# Epoch: 650 | Loss: 0.69416, Acc: 5.2e+01 | Test loss: 0.69415, Test accuracy: 51.50
# Epoch: 660 | Loss: 0.69413, Acc: 5.2e+01 | Test loss: 0.69413, Test accuracy: 51.50
# Epoch: 670 | Loss: 0.69411, Acc: 5.2e+01 | Test loss: 0.69412, Test accuracy: 51.50
# Epoch: 680 | Loss: 0.69409, Acc: 5.2e+01 | Test loss: 0.69410, Test accuracy: 51.50
# Epoch: 690 | Loss: 0.69407, Acc: 5.2e+01 | Test loss: 0.69409, Test accuracy: 51.50
# Epoch: 700 | Loss: 0.69405, Acc: 5.2e+01 | Test loss: 0.69407, Test accuracy: 51.50
# Epoch: 710 | Loss: 0.69403, Acc: 5.2e+01 | Test loss: 0.69406, Test accuracy: 51.50
# Epoch: 720 | Loss: 0.69401, Acc: 5.1e+01 | Test loss: 0.69405, Test accuracy: 51.50
# Epoch: 730 | Loss: 0.69399, Acc: 5.1e+01 | Test loss: 0.69403, Test accuracy: 51.00
# Epoch: 740 | Loss: 0.69397, Acc: 5.1e+01 | Test loss: 0.69402, Test accuracy: 51.00
# Epoch: 750 | Loss: 0.69395, Acc: 5.1e+01 | Test loss: 0.69401, Test accuracy: 51.00
# Epoch: 760 | Loss: 0.69393, Acc: 5.1e+01 | Test loss: 0.69400, Test accuracy: 51.00
# Epoch: 770 | Loss: 0.69391, Acc: 5.1e+01 | Test loss: 0.69398, Test accuracy: 51.00
# Epoch: 780 | Loss: 0.69390, Acc: 5.1e+01 | Test loss: 0.69397, Test accuracy: 51.00
# Epoch: 790 | Loss: 0.69388, Acc: 5.1e+01 | Test loss: 0.69396, Test accuracy: 51.00
# Epoch: 800 | Loss: 0.69386, Acc: 5.1e+01 | Test loss: 0.69395, Test accuracy: 51.00
# Epoch: 810 | Loss: 0.69385, Acc: 5.1e+01 | Test loss: 0.69394, Test accuracy: 51.00
# Epoch: 820 | Loss: 0.69383, Acc: 5.1e+01 | Test loss: 0.69393, Test accuracy: 51.00
# Epoch: 830 | Loss: 0.69382, Acc: 5.1e+01 | Test loss: 0.69392, Test accuracy: 51.00
# Epoch: 840 | Loss: 0.69380, Acc: 5.1e+01 | Test loss: 0.69391, Test accuracy: 51.50
# Epoch: 850 | Loss: 0.69379, Acc: 5.1e+01 | Test loss: 0.69390, Test accuracy: 51.50
# Epoch: 860 | Loss: 0.69377, Acc: 5.1e+01 | Test loss: 0.69389, Test accuracy: 51.50
# Epoch: 870 | Loss: 0.69376, Acc: 5.1e+01 | Test loss: 0.69388, Test accuracy: 51.50
# Epoch: 880 | Loss: 0.69374, Acc: 5.1e+01 | Test loss: 0.69388, Test accuracy: 51.50
# Epoch: 890 | Loss: 0.69373, Acc: 5.1e+01 | Test loss: 0.69387, Test accuracy: 51.50
# Epoch: 900 | Loss: 0.69372, Acc: 5.1e+01 | Test loss: 0.69386, Test accuracy: 51.50
# Epoch: 910 | Loss: 0.69370, Acc: 5.1e+01 | Test loss: 0.69385, Test accuracy: 51.50
# Epoch: 920 | Loss: 0.69369, Acc: 5.1e+01 | Test loss: 0.69384, Test accuracy: 51.50
# Epoch: 930 | Loss: 0.69368, Acc: 5.1e+01 | Test loss: 0.69384, Test accuracy: 51.50
# Epoch: 940 | Loss: 0.69367, Acc: 5.1e+01 | Test loss: 0.69383, Test accuracy: 51.50
# Epoch: 950 | Loss: 0.69365, Acc: 5.2e+01 | Test loss: 0.69382, Test accuracy: 51.50
# Epoch: 960 | Loss: 0.69364, Acc: 5.2e+01 | Test loss: 0.69382, Test accuracy: 51.50
# Epoch: 970 | Loss: 0.69363, Acc: 5.2e+01 | Test loss: 0.69381, Test accuracy: 51.50
# Epoch: 980 | Loss: 0.69362, Acc: 5.2e+01 | Test loss: 0.69381, Test accuracy: 51.50
# Epoch: 990 | Loss: 0.69361, Acc: 5.2e+01 | Test loss: 0.69380, Test accuracy: 51.50
